# %% [markdown]
# # Assignment: Libraries
#
# This problem set aims to develop your ability to use non-standard libraries such as NumPy, Pandas, Matplotlib, and requests.
#
# Please follow all instructions precisely.

# %% [markdown]
# ## Prerequisite: Install libraries
#
# To do this assignment, you need to have a few libraries installed. You already know how to install libraries in a basic Python virtual environment. In Anaconda, it is even easier.
#
# Install the following libraries:
# 1. Pandas
# 2. Requests
# 3. Matplotlib
#
# Follow this tutorial to install external libraries for your Jupyter notebook using the Anaconda Navigator.
#
# https://www.tutorialspoint.com/add-packages-to-anaconda-environment-in-python
#
# Once you are done, run the following cell. If it does nothing (i.e., if it throws no errors), then you may proceed.

# %%
# NON-EDITABLE CODE CELL
# You may run this cell, but do not edit it.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %% [markdown]
# ## Note
#
# 1. There is a good chance that you will have to look up how to do things using these libraries. This is fine. Just credit your sources appropriately.

# %% [markdown]
# ## Problem 1: Association Rules

# %% [markdown]
# ### Context
#
# You are a data consultant for a medium-sized grocery. Your job is to help the grocery's marketing and sales team identify the most frequent purchases of customers.

# %% [markdown]
# ### 1.1
#
# Read the file `sample order basket.csv` into a Pandas DataFrame called `df`.

# %%
# CODE CELL

# CODE START

file = open("sample order basket.csv")
df = pd.read_csv(file)
df

# CODE END
# Out:
#       OrderNum Product
# 0         1000    eggs
# 1         1001   bread
# 2         1002    eggs
# 3         1002   bread
# 4         1002   flour
# ...        ...     ...
# 1068      1496   bread
# 1069      1497     jam
# 1070      1498   bread
# 1071      1499    eggs
# 1072      1499   bread
#
# [1073 rows x 2 columns]

# %% [markdown]
# ### 1.2
#
# Create a "binary table" using a Pandas DataFrame. Save the DataFrame in a variable called `binary_table`.
#
# The specifications of the binary table are as follows:
# 1. The data in the binary table is based on the order log contained in `df`.
# 2. The index values of the binary table are the unique order IDs contained in the sales logs. These are arranged in ascending numerical order. Format the values as `int64`.
# 3. The column values of the binary table are the unique products contained in the sales logs. These are arranged in alphabetical order. Format the values as `object`.
# 4. The values of the binary table are either 0 or 1. A value will be 1 if the respective product is present in the respective order, and it will be 0 if the respective product is not present in the respective order. So, for example: if Order 5 ordered an apple, then the cell at row 5, column apple will have the value 1, and every other cell at row 5 will have the value 0.

# %%
# CODE CELL

# CODE START

ordernumbers = df["OrderNum"]
products = df["Product"]
uniqueproducts = products.unique()
uniqueproducts.sort()
binary_table = pd.DataFrame(index=ordernumbers, columns=uniqueproducts)
binary_table = binary_table.fillna(0)
binary_table = binary_table.loc[~binary_table.index.duplicated(), :]

for i in range(len(df)):
    for item in uniqueproducts:
        if df.loc[i, 'Product'] == item:
            binary_table.loc[df.loc[i, 'OrderNum'], item] = 1

binary_table

# CODE END
# Out:
#           bread  cheese  eggs  flour  jam
# OrderNum
# 1000          0       0     1      0    0
# 1001          1       0     0      0    0
# 1002          1       0     1      1    0
# 1003          1       0     1      0    1
# 1004          0       0     1      0    0
# ...         ...     ...   ...    ...  ...
# 1495          1       0     1      1    0
# 1496          1       1     1      0    0
# 1497          0       0     0      0    1
# 1498          1       0     0      0    0
# 1499          1       0     1      0    0
#
# [500 rows x 5 columns]

# %% [markdown]
# ### 1.3
#
# Using `binary_table`, create a report. Store this report in a Pandas DataFrame called `report`.
#
# The specifications of the report are as follows:
# 1. The data in the report is based on the data in `binary_table`.
# 2. The index values of `report` are simply the defaults (i.e., counting up from 0 to whatever number).
# 3. `report` has two columns: `combination` and `count`. The `combination` column will contain tuples that describe an order combination (e.g., ("apple", "eggplant")). Format the `combination` column as `object`. The `count` column will contain an integer value describing the number of times that this combination appeared in the list of orders. Format the `count` column as `int64`.
# 4. Sort `reports` by `count` in descending order. The order of combinations within each count bracket does not matter.
#
# You may use any standard library from Python 3.8 that you feel is necessary to complete this item. (This just means that you can use any standard Python library as long as it was in Python 3.8).

# %%
# CODE CELL

# CODE START

from collections import Counter

report = pd.DataFrame(columns=["combination", "count"])
items_list = list()

for i in range(len(binary_table)):
    new_list = list()
    for item in uniqueproducts:
        if binary_table.loc[i+1000, item] == 1:
            new_list.append(item)
    items_list.append(tuple(new_list))
    
counter = Counter(items_list)
report['combination'] = counter.keys()
report['combination'] = report['combination'].astype(object)
report['count'] = counter.values()
report['count'] = report['count'].astype(int)
report.sort_values(['count'],ascending=False,inplace=True)
report

# CODE END
# Out:
#                           combination  count
# 1                            (bread,)     65
# 4                        (bread, jam)     57
# 10                      (bread, eggs)     47
# 3                  (bread, eggs, jam)     46
# 0                             (eggs,)     31
# 14                             (jam,)     26
# 2                (bread, eggs, flour)     21
# 18                (bread, flour, jam)     18
# 21              (bread, cheese, eggs)     17
# 7                         (eggs, jam)     17
# 16                     (bread, flour)     15
# 17                    (bread, cheese)     15
# 12                          (cheese,)     13
# 11          (bread, eggs, flour, jam)     13
# 23               (bread, cheese, jam)     12
# 24                 (eggs, flour, jam)     11
# 25             (bread, cheese, flour)      9
# 9                            (flour,)      9
# 15                (cheese, eggs, jam)      8
# 13         (bread, cheese, eggs, jam)      7
# 6                       (cheese, jam)      7
# 19                     (cheese, eggs)      6
# 8                        (flour, jam)      6
# 5          (cheese, eggs, flour, jam)      6
# 20        (bread, cheese, flour, jam)      5
# 22                      (eggs, flour)      5
# 29       (bread, cheese, eggs, flour)      3
# 27                    (cheese, flour)      2
# 28  (bread, cheese, eggs, flour, jam)      2
# 26              (cheese, eggs, flour)      1

# %% [markdown]
# ## Problem 2: A Plot of the International Space Station's Location

# %% [markdown]
# We will only be checking the final output of this problem.
#
# ### Context
#
# You are a budding data scientist aiming to try your new tools on real-world data. As a pet project, you have decided that you want to try plotting the latitude and longitude positions of the International Space Station on a chart.
#
# An "application programming interface" (API) is an interface (i.e., a point of connection/use) that a program offers to other pieces of software. APIs are how modern computer programs interact. To massively oversimplify the concept, modern applications send and receive HTTP requests and JSON-formatted data to talk to each other.
#
# We will be using the ISS position data API hosted at http://open-notify.org/Open-Notify-API/ISS-Location-Now/ for this item.
#
# You are expected to read the documentation of this API for this item.

# %% [markdown]
# ### 2.1
#
# Use the `requests` library and the `time` library to collect position data of the ISS at intervals of 10 seconds over the course of 30 minutes by sending GET requests to the ISS API endpoint.
#
# The specifications of this problem are as follows:
# 1. Send a GET request to the ISS API endpoint once every 10 seconds for 30 minutes.
# 2. Each time you send a GET request, append the returned data to a list called `iss_data`.
# 3. Save all the data to a file called `iss-data.json` so that you do not lose it. You may do this every time you get a request if you wish.
# 4. Do not modify the returned data per GET request.
# 5. The final file `iss-data.json` should contain roughly 180 data points.
#
# We will not be strict about the time intervals. We will only look at the chart that you produce from your data.

# %%
# CODE CELL

# CODE START
import requests
import time
import json
import ast

datafile = open('iss-data.json','w')
file = open('testfile.txt', 'w')
datacount = 0
iss_data = []

while True:
    req = requests.get("http://api.open-notify.org/iss-now.json")
    iss_position = ast.literal_eval(req.content.decode('utf-8')) #https://stackoverflow.com/questions/49184578/how-to-convert-bytes-type-to-dictionary
    print(iss_position)
    iss_data.append(iss_position)
    datacount = datacount + 1
    if datacount >= 180:
        print(iss_data)
        datafile.write(json.dumps(iss_data))    
        print(str(iss_data))
        file.write(str(iss_data))
        print("Finished")
        break
    else:
        print(datacount)
        time.sleep(10)
   
    
# CODE END
# Out:
# {'iss_position': {'latitude': '48.9258', 'longitude': '-161.1666'}, 'timestamp': 1627966575, 'message': 'success'}
# 1
# {'iss_position': {'latitude': '48.7100', 'longitude': '-160.2813'}, 'timestamp': 1627966585, 'message': 'success'}
# 2
# {'iss_position': {'latitude': '48.4754', 'longitude': '-159.3604'}, 'timestamp': 1627966595, 'message': 'success'}
# 3
# {'iss_position': {'latitude': '48.2328', 'longitude': '-158.4485'}, 'timestamp': 1627966606, 'message': 'success'}
# 4
# {'iss_position': {'latitude': '47.9824', 'longitude': '-157.5459'}, 'timestamp': 1627966616, 'message': 'success'}
# 5
# {'iss_position': {'latitude': '47.7368', 'longitude': '-156.6949'}, 'timestamp': 1627966626, 'message': 'success'}
# 6
# {'iss_position': {'latitude': '47.4714', 'longitude': '-155.8105'}, 'timestamp': 1627966637, 'message': 'success'}
# 7
# {'iss_position': {'latitude': '47.1987', 'longitude': '-154.9355'}, 'timestamp': 1627966647, 'message': 'success'}
# 8
# {'iss_position': {'latitude': '46.8916', 'longitude': '-153.9881'}, 'timestamp': 1627966659, 'message': 'success'}
# 9
# {'iss_position': {'latitude': '46.6176', 'longitude': '-153.1737'}, 'timestamp': 1627966669, 'message': 'success'}
# 10
# {'iss_position': {'latitude': '46.3231', 'longitude': '-152.3279'}, 'timestamp': 1627966679, 'message': 'success'}
# 11
# {'iss_position': {'latitude': '46.0218', 'longitude': '-151.4918'}, 'timestamp': 1627966690, 'message': 'success'}
# 12
# {'iss_position': {'latitude': '45.7286', 'longitude': '-150.7045'}, 'timestamp': 1627966700, 'message': 'success'}
# 13
# {'iss_position': {'latitude': '45.4143', 'longitude': '-149.8870'}, 'timestamp': 1627966710, 'message': 'success'}
# 14
# {'iss_position': {'latitude': '45.0936', 'longitude': '-149.0794'}, 'timestamp': 1627966721, 'message': 'success'}
# 15
# {'iss_position': {'latitude': '44.7824', 'longitude': '-148.3191'}, 'timestamp': 1627966731, 'message': 'success'}
# 16
# {'iss_position': {'latitude': '44.4495', 'longitude': '-147.5301'}, 'timestamp': 1627966741, 'message': 'success'}
# 17
# {'iss_position': {'latitude': '44.1107', 'longitude': '-146.7506'}, 'timestamp': 1627966752, 'message': 'success'}
# 18
# {'iss_position': {'latitude': '43.7826', 'longitude': '-146.0171'}, 'timestamp': 1627966762, 'message': 'success'}
# 19
# {'iss_position': {'latitude': '43.4326', 'longitude': '-145.2561'}, 'timestamp': 1627966772, 'message': 'success'}
# 20
# {'iss_position': {'latitude': '43.0769', 'longitude': '-144.5045'}, 'timestamp': 1627966783, 'message': 'success'}
# 21
# {'iss_position': {'latitude': '42.7331', 'longitude': '-143.7973'}, 'timestamp': 1627966793, 'message': 'success'}
# 22
# {'iss_position': {'latitude': '42.3666', 'longitude': '-143.0630'}, 'timestamp': 1627966803, 'message': 'success'}
# 23
# {'iss_position': {'latitude': '41.9951', 'longitude': '-142.3383'}, 'timestamp': 1627966814, 'message': 'success'}
# 24
# {'iss_position': {'latitude': '41.6367', 'longitude': '-141.6566'}, 'timestamp': 1627966824, 'message': 'success'}
# 25
# {'iss_position': {'latitude': '41.2555', 'longitude': '-140.9495'}, 'timestamp': 1627966835, 'message': 'success'}
# 26
# {'iss_position': {'latitude': '40.8695', 'longitude': '-140.2512'}, 'timestamp': 1627966845, 'message': 'success'}
# 27
# {'iss_position': {'latitude': '40.4788', 'longitude': '-139.5616'}, 'timestamp': 1627966856, 'message': 'success'}
# 28
# {'iss_position': {'latitude': '40.0645', 'longitude': '-138.8482'}, 'timestamp': 1627966867, 'message': 'success'}
# 29
# {'iss_position': {'latitude': '39.6645', 'longitude': '-138.1760'}, 'timestamp': 1627966877, 'message': 'success'}
# 30
# {'iss_position': {'latitude': '39.2602', 'longitude': '-137.5120'}, 'timestamp': 1627966888, 'message': 'success'}
# 31
# {'iss_position': {'latitude': '38.8711', 'longitude': '-136.8872'}, 'timestamp': 1627966898, 'message': 'success'}
# 32
# {'iss_position': {'latitude': '38.4585', 'longitude': '-136.2390'}, 'timestamp': 1627966908, 'message': 'success'}
# 33
# {'iss_position': {'latitude': '38.0419', 'longitude': '-135.5987'}, 'timestamp': 1627966919, 'message': 'success'}
# 34
# {'iss_position': {'latitude': '37.6415', 'longitude': '-134.9961'}, 'timestamp': 1627966929, 'message': 'success'}
# 35
# {'iss_position': {'latitude': '37.2174', 'longitude': '-134.3710'}, 'timestamp': 1627966939, 'message': 'success'}
# 36
# {'iss_position': {'latitude': '36.7895', 'longitude': '-133.7534'}, 'timestamp': 1627966950, 'message': 'success'}
# 37
# {'iss_position': {'latitude': '36.3787', 'longitude': '-133.1721'}, 'timestamp': 1627966960, 'message': 'success'}
# 38
# {'iss_position': {'latitude': '35.9439', 'longitude': '-132.5688'}, 'timestamp': 1627966970, 'message': 'success'}
# 39
# {'iss_position': {'latitude': '35.5056', 'longitude': '-131.9726'}, 'timestamp': 1627966981, 'message': 'success'}
# 40
# {'iss_position': {'latitude': '35.0851', 'longitude': '-131.4114'}, 'timestamp': 1627966991, 'message': 'success'}
# 41
# {'iss_position': {'latitude': '34.6403', 'longitude': '-130.8287'}, 'timestamp': 1627967001, 'message': 'success'}
# 42
# {'iss_position': {'latitude': '34.1925', 'longitude': '-130.2529'}, 'timestamp': 1627967012, 'message': 'success'}
# 43
# {'iss_position': {'latitude': '33.7631', 'longitude': '-129.7105'}, 'timestamp': 1627967022, 'message': 'success'}
# 44
# {'iss_position': {'latitude': '33.3092', 'longitude': '-129.1473'}, 'timestamp': 1627967032, 'message': 'success'}
# 45
# {'iss_position': {'latitude': '32.8525', 'longitude': '-128.5905'}, 'timestamp': 1627967043, 'message': 'success'}
# 46
# {'iss_position': {'latitude': '32.4149', 'longitude': '-128.0659'}, 'timestamp': 1627967053, 'message': 'success'}
# 47
# {'iss_position': {'latitude': '31.9526', 'longitude': '-127.5209'}, 'timestamp': 1627967064, 'message': 'success'}
# 48
# {'iss_position': {'latitude': '31.4877', 'longitude': '-126.9819'}, 'timestamp': 1627967074, 'message': 'success'}
# 49
# {'iss_position': {'latitude': '31.0424', 'longitude': '-126.4738'}, 'timestamp': 1627967084, 'message': 'success'}
# 50
# {'iss_position': {'latitude': '30.5723', 'longitude': '-125.9460'}, 'timestamp': 1627967095, 'message': 'success'}
# 51
# {'iss_position': {'latitude': '30.0322', 'longitude': '-125.3495'}, 'timestamp': 1627967107, 'message': 'success'}
# 52
# {'iss_position': {'latitude': '29.5570', 'longitude': '-124.8335'}, 'timestamp': 1627967117, 'message': 'success'}
# 53
# {'iss_position': {'latitude': '29.1023', 'longitude': '-124.3468'}, 'timestamp': 1627967127, 'message': 'success'}
# 54
# {'iss_position': {'latitude': '28.6226', 'longitude': '-123.8408'}, 'timestamp': 1627967138, 'message': 'success'}
# 55
# {'iss_position': {'latitude': '28.1406', 'longitude': '-123.3398'}, 'timestamp': 1627967148, 'message': 'success'}
# 56
# {'iss_position': {'latitude': '27.6565', 'longitude': '-122.8437'}, 'timestamp': 1627967159, 'message': 'success'}
# 57
# {'iss_position': {'latitude': '27.1936', 'longitude': '-122.3758'}, 'timestamp': 1627967169, 'message': 'success'}
# 58
# {'iss_position': {'latitude': '26.7056', 'longitude': '-121.8890'}, 'timestamp': 1627967179, 'message': 'success'}
# 59
# {'iss_position': {'latitude': '26.2157', 'longitude': '-121.4068'}, 'timestamp': 1627967190, 'message': 'success'}
# 60
# {'iss_position': {'latitude': '25.7472', 'longitude': '-120.9516'}, 'timestamp': 1627967200, 'message': 'success'}
# 61
# {'iss_position': {'latitude': '25.2536', 'longitude': '-120.4779'}, 'timestamp': 1627967210, 'message': 'success'}
# 62
# {'iss_position': {'latitude': '24.7583', 'longitude': '-120.0085'}, 'timestamp': 1627967221, 'message': 'success'}
# 63
# {'iss_position': {'latitude': '24.2848', 'longitude': '-119.5651'}, 'timestamp': 1627967231, 'message': 'success'}
# 64
# {'iss_position': {'latitude': '23.7860', 'longitude': '-119.1035'}, 'timestamp': 1627967241, 'message': 'success'}
# 65
# {'iss_position': {'latitude': '23.2857', 'longitude': '-118.6458'}, 'timestamp': 1627967252, 'message': 'success'}
# 66
# {'iss_position': {'latitude': '22.8076', 'longitude': '-118.2134'}, 'timestamp': 1627967262, 'message': 'success'}
# 67
# {'iss_position': {'latitude': '22.3043', 'longitude': '-117.7630'}, 'timestamp': 1627967272, 'message': 'success'}
# 68
# {'iss_position': {'latitude': '21.7993', 'longitude': '-117.3161'}, 'timestamp': 1627967283, 'message': 'success'}
# 69
# {'iss_position': {'latitude': '21.3172', 'longitude': '-116.8937'}, 'timestamp': 1627967293, 'message': 'success'}
# 70
# {'iss_position': {'latitude': '20.8095', 'longitude': '-116.4535'}, 'timestamp': 1627967303, 'message': 'success'}
# 71
# {'iss_position': {'latitude': '20.3005', 'longitude': '-116.0166'}, 'timestamp': 1627967314, 'message': 'success'}
# 72
# {'iss_position': {'latitude': '19.8146', 'longitude': '-115.6034'}, 'timestamp': 1627967324, 'message': 'success'}
# 73
# {'iss_position': {'latitude': '19.3030', 'longitude': '-115.1725'}, 'timestamp': 1627967335, 'message': 'success'}
# 74
# {'iss_position': {'latitude': '18.7902', 'longitude': '-114.7446'}, 'timestamp': 1627967345, 'message': 'success'}
# 75
# {'iss_position': {'latitude': '18.2764', 'longitude': '-114.3196'}, 'timestamp': 1627967356, 'message': 'success'}
# 76
# {'iss_position': {'latitude': '17.7859', 'longitude': '-113.9174'}, 'timestamp': 1627967366, 'message': 'success'}
# 77
# {'iss_position': {'latitude': '17.2698', 'longitude': '-113.4977'}, 'timestamp': 1627967376, 'message': 'success'}
# 78
# {'iss_position': {'latitude': '16.7527', 'longitude': '-113.0807'}, 'timestamp': 1627967387, 'message': 'success'}
# 79
# {'iss_position': {'latitude': '16.2592', 'longitude': '-112.6858'}, 'timestamp': 1627967397, 'message': 'success'}
# 80
# {'iss_position': {'latitude': '15.7401', 'longitude': '-112.2735'}, 'timestamp': 1627967407, 'message': 'success'}
# 81
# {'iss_position': {'latitude': '15.2201', 'longitude': '-111.8636'}, 'timestamp': 1627967418, 'message': 'success'}
# 82
# {'iss_position': {'latitude': '14.7240', 'longitude': '-111.4753'}, 'timestamp': 1627967428, 'message': 'success'}
# 83
# {'iss_position': {'latitude': '14.2023', 'longitude': '-111.0697'}, 'timestamp': 1627967438, 'message': 'success'}
# 84
# {'iss_position': {'latitude': '13.6798', 'longitude': '-110.6662'}, 'timestamp': 1627967449, 'message': 'success'}
# 85
# {'iss_position': {'latitude': '13.1814', 'longitude': '-110.2838'}, 'timestamp': 1627967459, 'message': 'success'}
# 86
# {'iss_position': {'latitude': '12.6573', 'longitude': '-109.8841'}, 'timestamp': 1627967469, 'message': 'success'}
# 87
# {'iss_position': {'latitude': '12.1326', 'longitude': '-109.4863'}, 'timestamp': 1627967480, 'message': 'success'}
# 88
# {'iss_position': {'latitude': '11.6322', 'longitude': '-109.1090'}, 'timestamp': 1627967490, 'message': 'success'}
# 89
# {'iss_position': {'latitude': '11.1061', 'longitude': '-108.7145'}, 'timestamp': 1627967500, 'message': 'success'}
# 90
# {'iss_position': {'latitude': '10.5793', 'longitude': '-108.3215'}, 'timestamp': 1627967511, 'message': 'success'}
# 91
# {'iss_position': {'latitude': '10.0770', 'longitude': '-107.9486'}, 'timestamp': 1627967521, 'message': 'success'}
# 92
# {'iss_position': {'latitude': '9.5491', 'longitude': '-107.5585'}, 'timestamp': 1627967531, 'message': 'success'}
# 93
# {'iss_position': {'latitude': '9.0207', 'longitude': '-107.1697'}, 'timestamp': 1627967542, 'message': 'success'}
# 94
# {'iss_position': {'latitude': '8.5170', 'longitude': '-106.8007'}, 'timestamp': 1627967552, 'message': 'success'}
# 95
# {'iss_position': {'latitude': '7.9875', 'longitude': '-106.4143'}, 'timestamp': 1627967562, 'message': 'success'}
# 96
# {'iss_position': {'latitude': '7.4578', 'longitude': '-106.0291'}, 'timestamp': 1627967573, 'message': 'success'}
# 97
# {'iss_position': {'latitude': '6.9528', 'longitude': '-105.6632'}, 'timestamp': 1627967583, 'message': 'success'}
# 98
# {'iss_position': {'latitude': '6.4221', 'longitude': '-105.2799'}, 'timestamp': 1627967594, 'message': 'success'}
# 99
# {'iss_position': {'latitude': '5.8912', 'longitude': '-104.8975'}, 'timestamp': 1627967604, 'message': 'success'}
# 100
# {'iss_position': {'latitude': '5.3852', 'longitude': '-104.5341'}, 'timestamp': 1627967614, 'message': 'success'}
# 101
# {'iss_position': {'latitude': '4.8538', 'longitude': '-104.1534'}, 'timestamp': 1627967625, 'message': 'success'}
# 102
# {'iss_position': {'latitude': '4.3220', 'longitude': '-103.7732'}, 'timestamp': 1627967635, 'message': 'success'}
# 103
# {'iss_position': {'latitude': '3.8154', 'longitude': '-103.4118'}, 'timestamp': 1627967645, 'message': 'success'}
# 104
# {'iss_position': {'latitude': '3.2832', 'longitude': '-103.0328'}, 'timestamp': 1627967656, 'message': 'success'}
# 105
# {'iss_position': {'latitude': '2.7510', 'longitude': '-102.6543'}, 'timestamp': 1627967666, 'message': 'success'}
# 106
# {'iss_position': {'latitude': '2.2439', 'longitude': '-102.2941'}, 'timestamp': 1627967676, 'message': 'success'}
# 107
# {'iss_position': {'latitude': '1.7112', 'longitude': '-101.9162'}, 'timestamp': 1627967687, 'message': 'success'}
# 108
# {'iss_position': {'latitude': '1.1786', 'longitude': '-101.5386'}, 'timestamp': 1627967697, 'message': 'success'}
# 109
# {'iss_position': {'latitude': '0.5698', 'longitude': '-101.1072'}, 'timestamp': 1627967709, 'message': 'success'}
# 110
# {'iss_position': {'latitude': '0.0371', 'longitude': '-100.7299'}, 'timestamp': 1627967720, 'message': 'success'}
# 111
# {'iss_position': {'latitude': '-0.4703', 'longitude': '-100.3705'}, 'timestamp': 1627967730, 'message': 'success'}
# 112
# {'iss_position': {'latitude': '-1.0030', 'longitude': '-99.9931'}, 'timestamp': 1627967740, 'message': 'success'}
# 113
# {'iss_position': {'latitude': '-1.5356', 'longitude': '-99.6156'}, 'timestamp': 1627967751, 'message': 'success'}
# 114
# {'iss_position': {'latitude': '-2.0428', 'longitude': '-99.2558'}, 'timestamp': 1627967761, 'message': 'success'}
# 115
# {'iss_position': {'latitude': '-2.5753', 'longitude': '-98.8778'}, 'timestamp': 1627967771, 'message': 'success'}
# 116
# {'iss_position': {'latitude': '-3.1076', 'longitude': '-98.4995'}, 'timestamp': 1627967782, 'message': 'success'}
# 117
# {'iss_position': {'latitude': '-3.6144', 'longitude': '-98.1387'}, 'timestamp': 1627967792, 'message': 'success'}
# 118
# {'iss_position': {'latitude': '-4.1463', 'longitude': '-97.7595'}, 'timestamp': 1627967802, 'message': 'success'}
# 119
# {'iss_position': {'latitude': '-4.6779', 'longitude': '-97.3798'}, 'timestamp': 1627967813, 'message': 'success'}
# 120
# {'iss_position': {'latitude': '-5.1840', 'longitude': '-97.0175'}, 'timestamp': 1627967823, 'message': 'success'}
# 121
# {'iss_position': {'latitude': '-5.7152', 'longitude': '-96.6363'}, 'timestamp': 1627967833, 'message': 'success'}
# 122
# {'iss_position': {'latitude': '-6.2460', 'longitude': '-96.2544'}, 'timestamp': 1627967844, 'message': 'success'}
# 123
# {'iss_position': {'latitude': '-6.7512', 'longitude': '-95.8899'}, 'timestamp': 1627967854, 'message': 'success'}
# 124
# {'iss_position': {'latitude': '-7.2812', 'longitude': '-95.5064'}, 'timestamp': 1627967865, 'message': 'success'}
# 125
# {'iss_position': {'latitude': '-7.8109', 'longitude': '-95.1217'}, 'timestamp': 1627967875, 'message': 'success'}
# 126
# {'iss_position': {'latitude': '-8.3149', 'longitude': '-94.7544'}, 'timestamp': 1627967885, 'message': 'success'}
# 127
# {'iss_position': {'latitude': '-8.8437', 'longitude': '-94.3676'}, 'timestamp': 1627967896, 'message': 'success'}
# 128
# {'iss_position': {'latitude': '-9.3719', 'longitude': '-93.9795'}, 'timestamp': 1627967906, 'message': 'success'}
# 129
# {'iss_position': {'latitude': '-9.8996', 'longitude': '-93.5902'}, 'timestamp': 1627967917, 'message': 'success'}
# 130
# {'iss_position': {'latitude': '-10.4016', 'longitude': '-93.2182'}, 'timestamp': 1627967927, 'message': 'success'}
# 131
# {'iss_position': {'latitude': '-10.9283', 'longitude': '-92.8260'}, 'timestamp': 1627967937, 'message': 'success'}
# 132
# {'iss_position': {'latitude': '-11.4543', 'longitude': '-92.4323'}, 'timestamp': 1627967948, 'message': 'success'}
# 133
# {'iss_position': {'latitude': '-11.9546', 'longitude': '-92.0558'}, 'timestamp': 1627967958, 'message': 'success'}
# 134
# {'iss_position': {'latitude': '-12.4792', 'longitude': '-91.6589'}, 'timestamp': 1627967968, 'message': 'success'}
# 135
# {'iss_position': {'latitude': '-13.0031', 'longitude': '-91.2602'}, 'timestamp': 1627967979, 'message': 'success'}
# 136
# {'iss_position': {'latitude': '-13.5012', 'longitude': '-90.8788'}, 'timestamp': 1627967989, 'message': 'success'}
# 137
# {'iss_position': {'latitude': '-14.0236', 'longitude': '-90.4764'}, 'timestamp': 1627967999, 'message': 'success'}
# 138
# {'iss_position': {'latitude': '-14.5452', 'longitude': '-90.0719'}, 'timestamp': 1627968010, 'message': 'success'}
# 139
# {'iss_position': {'latitude': '-15.0411', 'longitude': '-89.6847'}, 'timestamp': 1627968020, 'message': 'success'}
# 140
# {'iss_position': {'latitude': '-15.5608', 'longitude': '-89.2761'}, 'timestamp': 1627968030, 'message': 'success'}
# 141
# {'iss_position': {'latitude': '-16.0797', 'longitude': '-88.8651'}, 'timestamp': 1627968041, 'message': 'success'}
# 142
# {'iss_position': {'latitude': '-16.5730', 'longitude': '-88.4715'}, 'timestamp': 1627968051, 'message': 'success'}
# 143
# {'iss_position': {'latitude': '-17.0898', 'longitude': '-88.0559'}, 'timestamp': 1627968061, 'message': 'success'}
# 144
# {'iss_position': {'latitude': '-17.6057', 'longitude': '-87.6377'}, 'timestamp': 1627968072, 'message': 'success'}
# 145
# {'iss_position': {'latitude': '-18.0959', 'longitude': '-87.2369'}, 'timestamp': 1627968082, 'message': 'success'}
# 146
# {'iss_position': {'latitude': '-18.6097', 'longitude': '-86.8134'}, 'timestamp': 1627968092, 'message': 'success'}
# 147
# {'iss_position': {'latitude': '-19.1222', 'longitude': '-86.3872'}, 'timestamp': 1627968103, 'message': 'success'}
# 148
# {'iss_position': {'latitude': '-19.6335', 'longitude': '-85.9579'}, 'timestamp': 1627968114, 'message': 'success'}
# 149
# {'iss_position': {'latitude': '-20.1192', 'longitude': '-85.5465'}, 'timestamp': 1627968124, 'message': 'success'}
# 150
# {'iss_position': {'latitude': '-20.6279', 'longitude': '-85.1114'}, 'timestamp': 1627968134, 'message': 'success'}
# 151
# {'iss_position': {'latitude': '-21.1353', 'longitude': '-84.6731'}, 'timestamp': 1627968145, 'message': 'success'}
# 152
# {'iss_position': {'latitude': '-21.6172', 'longitude': '-84.2525'}, 'timestamp': 1627968155, 'message': 'success'}
# 153
# {'iss_position': {'latitude': '-22.1220', 'longitude': '-83.8076'}, 'timestamp': 1627968165, 'message': 'success'}
# 154
# {'iss_position': {'latitude': '-22.6252', 'longitude': '-83.3592'}, 'timestamp': 1627968176, 'message': 'success'}
# 155
# {'iss_position': {'latitude': '-23.1031', 'longitude': '-82.9287'}, 'timestamp': 1627968186, 'message': 'success'}
# 156
# {'iss_position': {'latitude': '-23.6033', 'longitude': '-82.4731'}, 'timestamp': 1627968196, 'message': 'success'}
# 157
# {'iss_position': {'latitude': '-24.1018', 'longitude': '-82.0138'}, 'timestamp': 1627968207, 'message': 'success'}
# 158
# {'iss_position': {'latitude': '-24.5751', 'longitude': '-81.5726'}, 'timestamp': 1627968217, 'message': 'success'}
# 159
# {'iss_position': {'latitude': '-25.0703', 'longitude': '-81.1056'}, 'timestamp': 1627968227, 'message': 'success'}
# 160
# {'iss_position': {'latitude': '-25.5637', 'longitude': '-80.6343'}, 'timestamp': 1627968238, 'message': 'success'}
# 161
# {'iss_position': {'latitude': '-26.0320', 'longitude': '-80.1815'}, 'timestamp': 1627968248, 'message': 'success'}
# 162
# {'iss_position': {'latitude': '-26.5219', 'longitude': '-79.7019'}, 'timestamp': 1627968258, 'message': 'success'}
# 163
# {'iss_position': {'latitude': '-27.0098', 'longitude': '-79.2176'}, 'timestamp': 1627968269, 'message': 'success'}
# 164
# {'iss_position': {'latitude': '-27.4957', 'longitude': '-78.7290'}, 'timestamp': 1627968279, 'message': 'success'}
# 165
# {'iss_position': {'latitude': '-27.9565', 'longitude': '-78.2592'}, 'timestamp': 1627968289, 'message': 'success'}
# 166
# {'iss_position': {'latitude': '-28.4383', 'longitude': '-77.7612'}, 'timestamp': 1627968300, 'message': 'success'}
# 167
# {'iss_position': {'latitude': '-28.9863', 'longitude': '-77.1859'}, 'timestamp': 1627968312, 'message': 'success'}
# 168
# {'iss_position': {'latitude': '-29.4634', 'longitude': '-76.6771'}, 'timestamp': 1627968322, 'message': 'success'}
# 169
# {'iss_position': {'latitude': '-29.9156', 'longitude': '-76.1877'}, 'timestamp': 1627968332, 'message': 'success'}
# 170
# {'iss_position': {'latitude': '-30.3881', 'longitude': '-75.6687'}, 'timestamp': 1627968343, 'message': 'success'}
# 171
# {'iss_position': {'latitude': '-30.8581', 'longitude': '-75.1441'}, 'timestamp': 1627968353, 'message': 'success'}
# 172
# {'iss_position': {'latitude': '-31.3034', 'longitude': '-74.6395'}, 'timestamp': 1627968364, 'message': 'success'}
# 173
# {'iss_position': {'latitude': '-31.7684', 'longitude': '-74.1040'}, 'timestamp': 1627968374, 'message': 'success'}
# 174
# {'iss_position': {'latitude': '-32.2307', 'longitude': '-73.5626'}, 'timestamp': 1627968385, 'message': 'success'}
# 175
# {'iss_position': {'latitude': '-32.6684', 'longitude': '-73.0416'}, 'timestamp': 1627968395, 'message': 'success'}
# 176
# {'iss_position': {'latitude': '-33.1253', 'longitude': '-72.4886'}, 'timestamp': 1627968405, 'message': 'success'}
# 177
# {'iss_position': {'latitude': '-33.6009', 'longitude': '-71.9025'}, 'timestamp': 1627968416, 'message': 'success'}
# 178
# {'iss_position': {'latitude': '-34.0305', 'longitude': '-71.3635'}, 'timestamp': 1627968426, 'message': 'success'}
# 179
# {'iss_position': {'latitude': '-34.4786', 'longitude': '-70.7912'}, 'timestamp': 1627968437, 'message': 'success'}
# [{'iss_position': {'latitude': '48.9258', 'longitude': '-161.1666'}, 'timestamp': 1627966575, 'message': 'success'}, {'iss_position': {'latitude': '48.7100', 'longitude': '-160.2813'}, 'timestamp': 1627966585, 'message': 'success'}, {'iss_position': {'latitude': '48.4754', 'longitude': '-159.3604'}, 'timestamp': 1627966595, 'message': 'success'}, {'iss_position': {'latitude': '48.2328', 'longitude': '-158.4485'}, 'timestamp': 1627966606, 'message': 'success'}, {'iss_position': {'latitude': '47.9824', 'longitude': '-157.5459'}, 'timestamp': 1627966616, 'message': 'success'}, {'iss_position': {'latitude': '47.7368', 'longitude': '-156.6949'}, 'timestamp': 1627966626, 'message': 'success'}, {'iss_position': {'latitude': '47.4714', 'longitude': '-155.8105'}, 'timestamp': 1627966637, 'message': 'success'}, {'iss_position': {'latitude': '47.1987', 
{'latitude': '40.8695', 'longitude': '-140.2512'}, 'timestamp': 1627966845, 'message': 'success'}, {'iss_position': {'latitude': '40.4788', 'longitude': '-139.5616'}, 'timestamp': 1627966856, 'message': 'success'}, {'iss_position': {'latitude': '40.0645', 'longitude': '-138.8482'}, 'timestamp': 1627966867, 'message': 'success'}, {'iss_position': {'latitude': '39.6645', 'longitude': '-138.1760'}, 'timestamp': 1627966877, 'message': 'success'}, {'iss_position': {'latitude': '39.2602', 'longitude': '-137.5120'}, 'timestamp': 1627966888, 'message': 'success'}, {'iss_position': {'latitude': '38.8711', 'longitude': '-136.8872'}, 'timestamp': 1627966898, 'message': 'success'}, {'iss_position': {'latitude': '38.4585', 'longitude': '-136.2390'}, 'timestamp': 1627966908, 'message': 'success'}, {'iss_position': {'latitude': '38.0419', 'longitude': '-135.5987'}, 'timestamp': 1627966919, 'message': 'success'}, {'iss_position': {'latitude': '37.6415', 'longitude': ' ...
# Finished

# %% [markdown]
# ### 2.2
#
# Using the data you gathered and stored in `iss-data.json`, make a `matplotlib` plot of the location data.
#
# The specifications of this problem are as follows:
# 1. Use the longitude and latitude data contained in `iss-data.json` as your data.
# 2. Plot this data on a `matplotlib` plot that appropriately visualizes the data. It is up to you what specific plot you want to use as long as we, the human readers of your report, understand the message of your plot.
# 3. Use latitude as the X axis and longitude as the Y axis.
# 4. VERY IMPORTANT: Make sure that the chart displays in your Jupyter notebook before you submit.
#
# We will only check the chart. We do not care how you make it display as long as you follow the specifications.

# %%
# CODE CELL

# CODE START

import json
import matplotlib.pyplot as plt

latitude_list = []
longitude_list = []

issfile = open("iss-data.json", "r")
datadict = json.load(issfile)
for i in range(len(datadict)):
    latitude_list.append(float(datadict[i]['iss_position']['latitude']))
    longitude_list.append(float(datadict[i]['iss_position']['longitude']))
                          
fig = plt.figure()
axes = fig.add_axes([0, 0, 1, 1])
axes.plot(latitude_list,longitude_list, 'b')
axes.set_xlabel("latitude", fontsize=12, fontweight='bold')
axes.set_ylabel("longitude", fontsize=12, fontweight='bold')
axes.set_title("Path of the ISS from 8:56pm to 9:27pm of August 2, 2021", fontsize=15, fontweight='bold')
plt.gca().invert_xaxis()
plt.gca().invert_yaxis()
plt.grid()
plt.arrow(latitude_list[170],longitude_list[170], latitude_list[179]-latitude_list[170],longitude_list[179]-longitude_list[170],head_width=5,head_length=5,facecolor="Blue",edgecolor="Blue")


# CODE END

# %%
# !cat 'iss-data.json'
# Out:
# [{"iss_position": {"latitude": "48.9258", "longitude": "-161.1666"}, "timestamp": 1627966575, "message": "success"}, {"iss_position": {"latitude": "48.7100", "longitude": "-160.2813"}, "timestamp": 1627966585, "message": "success"}, {"iss_position": {"latitude": "48.4754", "longitude": "-159.3604"}, "timestamp": 1627966595, "message": "success"}, {"iss_position": {"latitude": "48.2328", "longitude": "-158.4485"}, "timestamp": 1627966606, "message": "success"}, {"iss_position": {"latitude": "47.9824", "longitude": "-157.5459"}, "timestamp": 1627966616, "message": "success"}, {"iss_position": {"latitude": "47.7368", "longitude": "-156.6949"}, "timestamp": 1627966626